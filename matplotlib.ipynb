# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a 2D plotting library for the Python programming language. It provides an object-oriented API for embedding plots into applications that use general-purpose GUI toolkits, such as Tkinter, wxPython, Qt, or GTK. It also provides a procedural interface named Pyplot, which is a collection of functions that make Matplotlib work like MATLAB.
#
# Matplotlib is used for creating static, animated, and interactive visualizations in Python. It is widely used for data visualization and exploration in various fields, including scientific research, data analysis, and machine learning.

# %% [markdown]
# 1. Line Plot:
#
#    Display data points connected by straight line segments.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Plot")
plt.show()

# %% [markdown]
# 2. Scatter Plot:
#
#     Display individual data points as markers.

# %%
import numpy as np

x = [1, 2, 3, 4, 5]
y = [5, 4, 6, 4, 3]


color = ['red','blue','yellow' ,'green','orange']
sizes = 10000 * np.random.rand(5)
plt.scatter(x,y,c=color,s=sizes)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# 3. Bar Plot:
#
#    Display rectangular bars to represent data.

# %%
x = ['A', 'B', 'C', 'D']
y = [3, 7, 2, 5]
plt.bar(x,y,color='g')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Bar Plot")
plt.show()

# %% [markdown]
# 4. Histogram:
#
#    Display the distribution of a dataset.

# %%
data = np.random.randn(100)

plt.hist(data,bins=20)
plt.show()

# %% [markdown]
# 5. Pie Chart:
#
#      Display the proportion of each part in a whole.

# %%
l = ['A', 'B', 'C', 'D']
s = [25, 30, 20, 25]

plt.pie(sizes, labels=labels , autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %% [markdown]
# A scatter plot is a type of data visualization that displays individual data points on a two-dimensional plane. Each point represents the values of two variables, and the position of the point is determined by the values of those variables. Scatter plots are useful for identifying relationships and patterns between two continuous variables.

# %%
color = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
plt.scatter(x,y,c=color,s=sizes,alpha=0.7)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %%
x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots within a single figure. It allows you to arrange subplots in a grid, specifying the number of rows and columns. This function is particularly useful when you want to compare multiple plots side by side or in a specific arrangement.

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot is a type of data visualization that represents categorical data with rectangular bars. The length of each bar corresponds to the value of the data it represents. Bar plots are used to compare and display the values of different categories, making it easy to identify trends or patterns within the data.

# %%
plt.figure(figsize=(10, 6))
plt.bar(company, profit, color=['blue', 'green', 'red', 'purple'])
plt.title('Bar Plot of Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color=['blue', 'green', 'red', 'purple'])
plt.title('Bar Plot of Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It displays the median, quartiles, and potential outliers in a compact and efficient manner. Box plots are useful for visualizing the spread and skewness of data, providing a summary of the data's central tendency and dispersion.

# %%
data = [box1, box2]

plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot of Two Datasets')
plt.ylabel('Values')
plt.show()
